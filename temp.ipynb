# %%
# 🧩 Cell 1: Define your strings
string2 = "purchase order no terms order no cust id order date sales rep page sold to: ship to: product id shipped description / size / brand st gross wt price amount westmans bagel & caffe dba westmans bagel & caffe dba tetia llc 2925 223rd pl sw brier, wa usa 98036 tetia llc 5201 university way ne b seattlebrier, wa usa 98105 fax: net 7 days 08/04/2025 date 08/05/2025 18 1 ordered per of 1 379183 ship via: # 1 03-tu / 6 route/stop: 18620 80th court south, bldg. f kent, wa 98032 www.pacificfoodimporters.com 102950 8.000 cs flour power cs 192.50 8.000 24.063 graincraft 157301 1.000 cs sesame seeds white+ 4 x cs 80.25 1.000 80.250 marca croc 33425 1.000 cs jalapeno sliced 6 # cs 51.33 1.000 51.329 savor 78825 x 1.000 ea currants ea 29.20 1.000 29.203 3210 3.000 cs milk oat 12 x 32 oz cs 119.84 3.000 39.948 oatley 109950 1.000 cs sugar granulated cane cs 28.59 1.000 28.587 c&h sugar 191928 1.000 cs eggs liquid 2 x cs 95.23 1.000 95.225 papettis sub total discount freight total 596.94 tax total $ 596.94 total weight ...... 626.67 . taxed - t st = status code: sub - s cash check# charge paid on acct"
string1 = "PURCHASE ORDER NO TERMS ORDER NO CUST ID ORDER DATE SALES REP Page Sold To: Ship To: PRODUCT ID SHIPPED DESCRIPTION / SIZE / BRAND ST GROSS WT PRICE AMOUNT WESTMANS BAGEL & CAFFE DBA WESTMANS BAGEL & CAFFE DBA TETIA LLC 2925 223rd PL SW BRIER, WA USA 98036 TETIA LLC 5201 UNIVERSITY WAY NE B SEATTLEBRIER, WA USA 98105 PH:352-502-8078 FAX: NET 7 DAYS 445630 6775 08/04/2025 INVOICE DATE 08/05/2025 18 1 ORDERED per of 1 379183 Ship Via: # 1 INVOICE 03-TU / 6 Route/Stop: 18620 80th COURT SOUTH, BLDG."

# %%
# 🧠 Cell 2: Case-sensitive comparison
if string1 == string2:
    print("✅ The strings are identical (case-sensitive).")
else:
    print("❌ The strings are NOT identical (case-sensitive).")
# Out:
# ❌ The strings are NOT identical (case-sensitive).
